# %% [markdown]
# DAY 1

# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.3 is available.
# You should consider upgrading via the 'C:\Users\ASUS\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Matplotlib:", plt.matplotlib.__version__)
print("Seaborn:", sns.__version__)
# Out:
# Pandas: 2.3.3
# NumPy: 2.2.6
# Matplotlib: 3.10.8
# Seaborn: 0.13.2

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\archive\diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Glucose'].head()
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
df.iloc[0:5]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.loc[0:4, ['Glucose', 'BMI', 'Age']]
# Out:
#    Glucose   BMI  Age
# 0      148  33.6   50
# 1       85  26.6   31
# 2      183  23.3   32
# 3       89  28.1   21
# 4      137  43.1   33

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']
print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (768, 8)
# Target shape: (768,)

# %% [markdown]
# DAY 2

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
z = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
plt.figure(figsize=(10,5))
sns.boxplot(data=df[z])
plt.title("Boxplot for Detecting Outliers")
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title("Outcome vs Glucose Level")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title("Outcome vs BMI")
plt.show()

# %%
df.hist(figsize=(12,10), bins=20)
plt.suptitle("Histogram of Numerical Features")
plt.show()

# %% [markdown]
# DAY 3

# %%
df.hist(figsize=(14, 12), bins=20)
plt.suptitle("Histograms of Numerical Features", fontsize=16)
plt.show()

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# DAY 4

# %%
z = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
df[z] = df[z].replace(0, np.nan)
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
for column in z:
    df[column].fillna(df[column].median(), inplace=True)
df.isnull().sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24752\2080202589.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].median(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24752\2080202589.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.656250      72.386719      29.108073  140.671875
# std       3.369578   30.438286      12.096642       8.791221   86.383060
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      25.000000  121.500000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.455208                  0.471876   33.240885    0.348958
# std      6.875177                  0.331329   11.760232    0.476951
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# DAY 5

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (614, 8)
# X_test shape: (154, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = log_reg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7142857142857143

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[82 18]
#  [26 28]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79       100
#            1       0.61      0.52      0.56        54
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.67      0.67       154
# weighted avg       0.71      0.71      0.71       154

# %% [markdown]
# DAY 6

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %%
k_values = range(1, 21)
accuracy_scores = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# %%
plt.figure(figsize=(6,4))
plt.plot(k_values, accuracy_scores, marker='o')
plt.xlabel("Value of K")
plt.ylabel("Accuracy")
plt.title("KNN Accuracy for Different K Values")
plt.show()

# %%
best_k = k_values[accuracy_scores.index(max(accuracy_scores))]
print("Best K value:", best_k)
# Out:
# Best K value: 12

# %%
knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %%
print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_knn))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.7727272727272727
# Confusion Matrix:
#  [[89 11]
#  [24 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84       100
#            1       0.73      0.56      0.63        54
#
#     accuracy                           0.77       154
#    macro avg       0.76      0.72      0.73       154
# weighted avg       0.77      0.77      0.76       154

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(16,8))
plot_tree(
    dt,
    feature_names=X.columns,
    class_names=['Non-Diabetic', 'Diabetic'],
    filled=True
)
plt.title("Decision Tree Structure")
plt.show()

# %%
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.7207792207792207
# Confusion Matrix:
#  [[85 15]
#  [28 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.85      0.80       100
#            1       0.63      0.48      0.55        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.67      0.67       154
# weighted avg       0.71      0.72      0.71       154

# %% [markdown]
# DAY 7

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
model_performance = {
    "Logistic Regression": {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1 Score": f1_score(y_test, y_pred)
    },
    "KNN": {
        "Accuracy": accuracy_score(y_test, y_pred_knn),
        "Precision": precision_score(y_test, y_pred_knn),
        "Recall": recall_score(y_test, y_pred_knn),
        "F1 Score": f1_score(y_test, y_pred_knn)
    },
    "Decision Tree": {
        "Accuracy": accuracy_score(y_test, y_pred_dt),
        "Precision": precision_score(y_test, y_pred_dt),
        "Recall": recall_score(y_test, y_pred_dt),
        "F1 Score": f1_score(y_test, y_pred_dt)
    }
}

# %%
performance_df = pd.DataFrame(model_performance).T
performance_df
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# Logistic Regression  0.740260   0.684211  0.481481  0.565217
# KNN                  0.772727   0.731707  0.555556  0.631579
# Decision Tree        0.720779   0.634146  0.481481  0.547368

# %%
performance_df.sort_values(by="F1 Score", ascending=False)
# Out:
#                      Accuracy  Precision    Recall  F1 Score
# KNN                  0.772727   0.731707  0.555556  0.631579
# Logistic Regression  0.740260   0.684211  0.481481  0.565217
# Decision Tree        0.720779   0.634146  0.481481  0.547368

# %% [markdown]
#  Observations:
# 1. Glucose is the most influential feature across all models
# 2. Logistic Regression showed consistent performance
# 3. KNN performance depended heavily on K value
# 4. Decision Tree showed signs of overfitting
# 5. Feature scaling significantly improved KNN performance

# %% [markdown]
#  Conclusion:
# 1. In this project, multiple machine learning models were implemented
# 2. to predict diabetes using the PIMA Indians Diabetes dataset.
# 3. After comparing Logistic Regression, KNN, and Decision Tree models,
# 4. Logistic Regression was selected as the best-performing model.
# 5. Proper data cleaning, feature scaling, and model evaluation
# 6. contributed significantly to the accuracy of the system.
# 7. This model can assist healthcare professionals in early
# 8. diabetes detection and decision-making.

# %% [markdown]
# DAY 8

# %% [markdown]
# The objective of this project is to analyze the Student Performance dataset and build a regression model to predict students' academic performance based on various academic, personal, and socio-economic factors.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ASUS\Downloads\Student_Performance.csv")
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes          NaN
# 1              4               82                         No          4.0
# 2              8               51                        Yes          7.0
# 3              5               52                        Yes          5.0
# 4              7               75                         No          NaN
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                         float64
# Sample Question Papers Practiced      int64
# Performance Index                     int64
# dtype: object

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores  Sleep Hours  \
# count   10000.000000     10000.000000  9998.000000
# mean        4.992900        69.445700     6.530206
# std         2.589309        17.343152     1.695789
# min         1.000000        40.000000     4.000000
# 25%         3.000000        54.000000     5.000000
# 50%         5.000000        69.000000     7.000000
# 75%         7.000000        85.000000     8.000000
# max         9.000000        99.000000     9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         2
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df['Hours Studied'].head()
# Out:
# 0    7
# 1    4
# 2    8
# 3    5
# 4    7
# Name: Hours Studied, dtype: int64

# %%
df.iloc[0:5]
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes          NaN
# 1              4               82                         No          4.0
# 2              8               51                        Yes          7.0
# 3              5               52                        Yes          5.0
# 4              7               75                         No          NaN
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
df.loc[0:4, ['Hours Studied', 'Sleep Hours', 'Performance Index']]
# Out:
#    Hours Studied  Sleep Hours  Performance Index
# 0              7          NaN                 91
# 1              4          4.0                 65
# 2              8          7.0                 45
# 3              5          5.0                 36
# 4              7          NaN                 66

# %%
X = df.drop('Performance Index', axis=1)
y = df['Performance Index']
print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (10000, 5)
# Target shape: (10000,)

# %% [markdown]
# DAY 9

# %%
z = [
    'Hours Studied',
    'Previous Scores',
    'Sleep Hours',
    'Sample Question Papers Practiced'
]
df[z] = df[z].replace(0, np.nan)
df.isnull().sum()
# Out:
# Hours Studied                         0
# Previous Scores                       0
# Extracurricular Activities            0
# Sleep Hours                           2
# Sample Question Papers Practiced    951
# Performance Index                     0
# dtype: int64

# %%
for column in z:
    df[column].fillna(df[column].median(), inplace=True)
df.isnull().sum()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24752\2080202589.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].median(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24752\2080202589.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530300
# std         2.589309        17.343152      1.695632
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           5.058800          55.224800
# std                            2.452375          19.212558
# min                            1.000000          10.000000
# 25%                            3.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(148)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# DAY 10

# %%
numerical_columns = [
    'Hours Studied', 
    'Previous Scores', 
    'Sleep Hours', 
    'Sample Question Papers Practiced', 
    'Performance Index'
]
df[numerical_columns].hist(figsize=(12,10), bins=20)
plt.suptitle("Histogram of Numerical Features", fontsize=16)
plt.show()

# %%
df[numerical_columns].skew()
# Out:
# Hours Studied                      -0.002502
# Previous Scores                     0.004532
# Sleep Hours                        -0.039835
# Sample Question Papers Practiced   -0.024076
# Performance Index                  -0.001397
# dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numerical_columns])
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
df['Extracurricular Activities'] = df['Extracurricular Activities'].map({'No': 0, 'Yes': 1})

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap (All Features Numeric)")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
X = df.drop('Performance Index', axis=1)
y = df['Performance Index']
scaler = StandardScaler()
X_scaled = X.copy()
X_scaled[numerical_columns[:-1]] = scaler.fit_transform(X[numerical_columns[:-1]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (7881, 5)
# X_test shape: (1971, 5)
# y_train shape: (7881,)
# y_test shape: (1971,)

# %% [markdown]
# DAY 11

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
r2_lr = r2_score(y_test, y_pred_lr)
print("Linear Regression Performance:")
print(f"MAE: {mae_lr:.2f}, RMSE: {rmse_lr:.2f}, R²: {r2_lr:.2f}")
# Out:
# Linear Regression Performance:
# MAE: 1.63, RMSE: 2.04, R²: 0.99

# %%
from sklearn.neighbors import KNeighborsRegressor
k_values = range(1, 21)
r2_scores = []

for k in k_values:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    r2_scores.append(r2_score(y_test, y_pred))

plt.figure(figsize=(6,4))
plt.plot(k_values, r2_scores, marker='o')
plt.xlabel("K value")
plt.ylabel("R² Score")
plt.title("KNN Regressor: R² vs K")
plt.show()
best_k = k_values[r2_scores.index(max(r2_scores))]
print("Best K for KNN:", best_k)
knn = KNeighborsRegressor(n_neighbors=best_k)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
mae_knn = mean_absolute_error(y_test, y_pred_knn)
mse_knn = mean_squared_error(y_test, y_pred_knn)
rmse_knn = np.sqrt(mse_knn)
r2_knn = r2_score(y_test, y_pred_knn)
print("KNN Regressor Performance:")
print(f"MAE: {mae_knn:.2f}, RMSE: {rmse_knn:.2f}, R²: {r2_knn:.2f}")
# Out:
# Best K for KNN: 8
# KNN Regressor Performance:
# MAE: 2.31, RMSE: 2.91, R²: 0.98

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
mae_dt = mean_absolute_error(y_test, y_pred_dt)
mse_dt = mean_squared_error(y_test, y_pred_dt)
rmse_dt = np.sqrt(mse_dt)
r2_dt = r2_score(y_test, y_pred_dt)
print("Decision Tree Regressor Performance:")
print(f"MAE: {mae_dt:.2f}, RMSE: {rmse_dt:.2f}, R²: {r2_dt:.2f}")
# Out:
# Decision Tree Regressor Performance:
# MAE: 2.41, RMSE: 3.03, R²: 0.97

# %%
plt.figure(figsize=(16,8))
plot_tree(dt, feature_names=X.columns, filled=True)
plt.title("Decision Tree Structure")
plt.show()

# %%
comparison = pd.DataFrame({
    "Model": ["Linear Regression", "KNN Regressor", "Decision Tree Regressor"],
    "MAE": [mae_lr, mae_knn, mae_dt],
    "RMSE": [rmse_lr, rmse_knn, rmse_dt],
    "R²": [r2_lr, r2_knn, r2_dt]
})
comparison
# Out:
#                      Model       MAE      RMSE        R²
# 0        Linear Regression  1.625408  2.043069  0.988568
# 1            KNN Regressor  2.305809  2.907872  0.976842
# 2  Decision Tree Regressor  2.405970  3.027527  0.974897

# %%
best_model_index = comparison['R²'].idxmax()
best_model = comparison.iloc[best_model_index]
print("Best Model Selected:")
print(best_model)
# Out:
# Best Model Selected:
# Model    Linear Regression
# MAE               1.625408
# RMSE              2.043069
# R²                0.988568
# Name: 0, dtype: object

# %% [markdown]
#  Observations:
# Hours Studied and Previous Scores are the most influential features
# KNN performance depends on optimal K
# Decision Tree may overfit small datasets
# Linear Regression is simple, interpretable, and often performs well

# %% [markdown]
# Conclusions:
# Multiple regression models were trained to predict Performance Index
# Linear Regression, KNN, and Decision Tree models were evaluated using MAE, RMSE, and R²
# Based on performance metrics, the model with the highest R² and lowest RMSE is selected
# This predictive model can help identify factors affecting student performance and support data-driven interventions
